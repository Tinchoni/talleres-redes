# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
red1 = pd.read_csv("tabla_red1.csv",index_col=0)
red2 = pd.read_csv("tabla_red_fel.csv",index_col=0)
red3 = pd.read_csv("tabla_red3_tinchoni.csv",index_col=0)
red4 = pd.read_csv("tabla_red4.csv",index_col=0)


horarios = [hora for hora in range(10,20)]
red1 = red1.loc[horarios]
red2 = red2.loc[horarios]
red3 = red3.loc[horarios]
red4 = red4.loc[horarios]

# %%
sns.set_style("darkgrid")

entropia

plt.title("Entropia por hora")
plt.xticks(rotation=65)
plt.plot(horario,entropia_red1)
plt.plot(x,entropia_red2)
plt.legend(['Red1', 'Red2'])

# %%
sns.set_style("darkgrid")

plt.title("Paquetes por hora")
plt.xticks(rotation=65)
plt.plot(x,paquetes_red1)
plt.legend(['Red1'])

# %%
casts = red1[["Uni%","Broad%"]]

casts.plot.bar(y=['Uni%','Broad%'], stacked=True, rot=45)

# %%
protocolo_red1 = red1[["2048%", " 2054%"," 33024%","34999%"," 34525%"]]
protocolo_red2 = red2[["2048%", " 2054%"," 33024%","34999%"," 34525%"]]
protocolo_red3 = red3[["2048%", " 2054%"," 33024%","34999%"," 34525%"]]
protocolo_red4 = red4[["2048%", " 2054%"," 33024%","34999%"," 34525%"]]

figure, axes = plt.subplots(2,2,figsize=(20,15))
fig=axes[0,0].figure
fig.suptitle('Porcentaje de los Protocolos', fontsize=40)
horario = [hora for hora in range(10,20)]

#Plot red1
axes[0][0].set_title("Red1", fontsize=25)
axes[0][0].set_xlabel('Horario', fontsize=20) # Use argument `labelpad` to move label downwards.
axes[0][0].set_ylabel('Porcentaje', fontsize=20)

protocolo_red1.loc[horario].plot.bar(ax=axes[0][0] ,y=["2048%", " 2054%"," 33024%","34999%"," 34525%"], stacked=True, rot=90)
#axes[0][0].legend(['line A', 'line B',"c","d","e"])
######
#Plot red2
axes[0][1].set_title("Red2", fontsize=25)
axes[0][1].set_xlabel('Horario', fontsize=20) # Use argument `labelpad` to move label downwards.
axes[0][1].set_ylabel('Porcentaje', fontsize=20)

protocolo_red2.loc[horario].plot.bar(ax=axes[0][1] ,y=["2048%", " 2054%"," 33024%","34999%"," 34525%"], stacked=True, rot=90)
#axes[0][0].legend(['line A', 'line B',"c","d","e"])
#Plot red3
axes[1][0].set_title("Red3", fontsize=25)
axes[1][0].set_xlabel('Horario', fontsize=20) # Use argument `labelpad` to move label downwards.
axes[1][0].set_ylabel('Porcentaje', fontsize=20)

protocolo_red3.loc[horario].plot.bar(ax=axes[1][0] ,y=["2048%", " 2054%"," 33024%","34999%"," 34525%"], stacked=True, rot=90)
#axes[0][0].legend(['line A', 'line B',"c","d","e"])
#Plot red4
axes[1][1].set_title("Red4", fontsize=25)
axes[1][1].set_xlabel('Horario', fontsize=20) # Use argument `labelpad` to move label downwards.
axes[1][1].set_ylabel('Porcentaje', fontsize=20)

protocolo_red4.loc[horario].plot.bar(ax=axes[1][1] ,y=["2048%", " 2054%"," 33024%","34999%"," 34525%"], stacked=True, rot=90)
#axes[0][0].legend(['line A', 'line B',"c","d","e"])

figure.savefig("Porcentaje_protocolos.png")

# %%
cast_red1 = red1[["Uni%","Broad%"]]
cast_red2 = red2[["Uni%","Broad%"]]
cast_red3 = red3[["Uni%","Broad%"]]
cast_red4 = red4[["Uni%","Broad%"]]
params = {'legend.fontsize': 20,
          'legend.handlelength': 2}

figure, axes = plt.subplots(2,2,figsize=(20,15))
fig=axes[0,0].figure
fig.suptitle('Porcentaje de los Unicast contra Broadcast', fontsize=40)
horario = [hora for hora in range(10,20)]

#Plot red1
axes[0][0].set_title("Red1", fontsize=25)
axes[0][0].set_xlabel('Horario', fontsize=20) # Use argument `labelpad` to move label downwards.
axes[0][0].set_ylabel('Porcentaje', fontsize=20)

cast_red1.loc[horario].plot.bar(ax=axes[0][0] ,y=["Uni%","Broad%"], stacked=True, rot=90)
#axes[0][0].legend(['line A', 'line B',"c","d","e"])
######
#Plot red2
axes[0][1].set_title("Red2", fontsize=25)
axes[0][1].set_xlabel('Horario', fontsize=20) # Use argument `labelpad` to move label downwards.
axes[0][1].set_ylabel('Porcentaje', fontsize=20)

cast_red2.loc[horario].plot.bar(ax=axes[0][1] ,y=["Uni%","Broad%"], stacked=True, rot=90)
#axes[0][0].legend(['line A', 'line B',"c","d","e"])
#Plot red3
axes[1][0].set_title("Red3", fontsize=25)
axes[1][0].set_xlabel('Horario', fontsize=20) # Use argument `labelpad` to move label downwards.
axes[1][0].set_ylabel('Porcentaje', fontsize=20)

cast_red3.loc[horario].plot.bar(ax=axes[1][0] ,y=["Uni%","Broad%"], stacked=True, rot=90)
#axes[0][0].legend(['line A', 'line B',"c","d","e"])
#Plot red4
axes[1][1].set_title("Red4", fontsize=25)
axes[1][1].set_xlabel('Horario', fontsize=20) # Use argument `labelpad` to move label downwards.
axes[1][1].set_ylabel('Porcentaje', fontsize=20)

cast_red4.loc[horario].plot.bar(ax=axes[1][1] ,y=["Uni%","Broad%"], stacked=True, rot=90)
#axes[0][0].legend(['line A', 'line B',"c","d","e"])

figure.savefig("Porcentaje_Cast.png")

# %%
from math  import log2
entropia_red1 = red1[["Entropia"]]
entropia_red2 = red2[["Entropia"]]
entropia_red3 = red3[["Entropia"]]
entropia_red4 = red4[["Entropia"]]

CANT_SIMBOLOS_red1 = 5
entropia_maxima_red1 = log2(CANT_SIMBOLOS_red1)
y_red1 = [entropia_maxima_red1 for x in range(10,20)]
CANT_SIMBOLOS_red2 = 3
entropia_maxima_red2 = log2(CANT_SIMBOLOS_red2)
y_red2 = [entropia_maxima_red2 for x in range(10,20)]
CANT_SIMBOLOS_red3 = 3
entropia_maxima_red3 = log2(CANT_SIMBOLOS_red3)
y_red3 = [entropia_maxima_red3 for x in range(10,20)]
CANT_SIMBOLOS_red4 = 2
entropia_maxima_red4 = log2(CANT_SIMBOLOS_red4)
y_red4 = [entropia_maxima_red4 for x in range(10,20)]
figure, axes = plt.subplots(2,2,figsize=(20,15))
fig=axes[0,0].figure
fig.suptitle('Entropia de la fuente', fontsize=40)
horario = [hora for hora in range(10,20)]

#Plot red1
axes[0][0].set_title("Red1", fontsize=25)
axes[0][0].set_xlabel('Horario', fontsize=20) # Use argument `labelpad` to move label downwards.
axes[0][0].set_ylabel('Valor', fontsize=20)
axes[0][0].plot(horarios, y_red1,color='r', linestyle='dotted')
entropia_red1.loc[horario].plot(ax=axes[0][0] ,y=["Entropia"],  rot=90)
axes[0][0].legend(["Entropia Maxima","Entropia de la red"])
#Plot red2
axes[0][1].set_title("Red2", fontsize=25)
axes[0][1].set_xlabel('Horario', fontsize=20) # Use argument `labelpad` to move label downwards.
axes[0][1].set_ylabel('Valor', fontsize=20)
axes[0][1].plot(horarios, y_red2,color='r', linestyle='dotted')
entropia_red2.loc[horario].plot(ax=axes[0][1] ,y=["Entropia"],  rot=90)
axes[0][1].legend(["Entropia Maxima","Entropia de la red"])
#Plot red3
axes[1][0].set_title("Red3", fontsize=25)
axes[1][0].set_xlabel('Horario', fontsize=20) # Use argument `labelpad` to move label downwards.
axes[1][0].set_ylabel('Valor', fontsize=20)
axes[1][0].plot(horarios, y_red3,color='r', linestyle='dotted')
entropia_red3.loc[horario].plot(ax=axes[1][0] ,y=["Entropia"],  rot=90)
axes[1][0].legend(["Entropia Maxima","Entropia de la red"])
#Plot red1
axes[1][1].set_title("Red4", fontsize=25)
axes[1][1].set_xlabel('Horario', fontsize=20) # Use argument `labelpad` to move label downwards.
axes[1][1].set_ylabel('Valor', fontsize=20)
axes[1][1].plot(horarios, y_red4,color='r', linestyle='dotted')
entropia_red4.loc[horario].plot(ax=axes[1][1] ,y=["Entropia"],  rot=90)
axes[1][1].legend(["Entropia Maxima","Entropia de la red"])

figure.savefig("Entropia.png")

# %%
import numpy as np

red1 = pd.read_csv("tabla_red1.csv",index_col=0)

red1 = red1["Paquetes"].loc[16]
red4 = pd.read_csv("tabla_utorrent.csv",index_col=0)
red4 = red4["Paquetes"]
sns.set_style("darkgrid")
horario = 16

objects =  ""
plt.title("Paquetes descargados", fontsize=25)
plt.bar(" ",red1 )
plt.bar("  ",red4)
plt.yticks(np.arange(100000, 1500000, 200000))
plt.ylabel('Paquetes', fontsize=20)
plt.legend(['Uso normal', 'Descargando archivo por torrent'])
plt.savefig("Paquetes.png")
